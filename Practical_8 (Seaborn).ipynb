# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Create the heatmap directly from the correlation matrix of numerical columns
sns.heatmap(tips.select_dtypes(include=['float64', 'int64']).corr(), annot=True, cmap='coolwarm', linewidths=0.5, vmin=-1, vmax=1)

# Set the title and show the plot
plt.title("Correlation Heatmap of Tips Dataset")
plt.show()

# %%
#heatmap with values
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
#joint plot for tip and total_bill
sns.jointplot(x='tip',y='total_bill',data=df)

# %%
#jointplot hex
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %%
#joint plot for tip and total_bill with regression line
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')

# %%
#pairplot
sns.pairplot(df,hue='sex')
# Out:
# C:\Users\DSBDALAB24\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#distplot
sns.distplot(df['tip'],color='blue', bins=20)
# Out:
# C:\Users\DSBDALAB24\AppData\Local\Temp\ipykernel_11364\2068815296.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['tip'],color='blue', bins=20)
# <Axes: xlabel='tip', ylabel='Density'>

# %%
#rugplot
sns.rugplot(df['tip'])
# Out:
# <Axes: xlabel='tip'>

# %%
#categorical plot
sns.barplot(x='sex', y='total_bill', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
#countplot
sns.countplot(x='sex', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#boxplot
sns.boxplot(x='sex', y='tip', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
#box plot with hue
sns.boxplot(x='sex', y='tip', data=df, hue="smoker")
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
#violin plot 
sns.violinplot(x='sex', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>
